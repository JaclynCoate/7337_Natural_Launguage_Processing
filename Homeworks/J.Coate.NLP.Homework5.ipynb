# %% [markdown]
# ## DS 7337: Natural Language Processing
#
# ## Jaclyn Coate
# ## Homework 5
#
# #### Spring 2021
# #### Natural Language Processing w/ Python: Bird, Klein, & Loper

# %%
# Environment Prep
import bs4; print( 'bs4 ' + bs4.__version__)
from bs4 import BeautifulSoup, SoupStrainer

import nltk; print( 'nltk ' + nltk.__version__)
from nltk import word_tokenize, pos_tag, RegexpParser;
from nltk.tokenize import sent_tokenize

import re; print('re ' + re.__version__)
import requests; print('requests ' + requests.__version__)
# Out:
# bs4 4.8.2
# nltk 3.4.5
# re 2.2.1
# requests 2.22.0

# %% [markdown]
# ##### HW 5: Question 1
# Compile a list of static links (permalinks) to individual user movie reviews from one particular website. This will be your working dataset for this assignment, as well as for assignments 7 and 8, which together will make up your semester project.
#
# a. It does not matter if you use a crawler or if you manually collect the links, but you will need at least 100 movie review links. Note that, as of this writing, the robots.txt file of IMDB.com allows the crawling of user reviews.
#
# b. Each link should be to a web page that has only one user review of only one movie, e.g., the user review permalinks on the IMDB site.
#
# c.	Choose reviews of movies that are all in the same genre, e.g., sci-fi, mystery, romance, superhero, etc.
#
# d.	Make sure your collection includes reviews of several movies in your chosen genre and that it includes a mix of negative and positive reviews.

# %%
# Source links for Top Horror Movies in History and store in review_home_url
review_home_url = {
    'The Exorcist': 'https://www.imdb.com/title/tt0070047/reviews?ref_=tt_ql_3',
    'Paranormal Activity': 'https://www.imdb.com/title/tt1179904/reviews?ref_=tt_ql_3',
    'Hellraiser': 'https://www.imdb.com/title/tt0093177/reviews?ref_=tt_ql_3',
    'A Nightmare on Elm Street': 'https://www.imdb.com/title/tt0087800/reviews?ref_=tt_ql_3',
    'American Psycho' : 'https://www.imdb.com/title/tt0087800/reviews?ref_=tt_ql_3',
    'The Blair Witch Project': 'https://www.imdb.com/title/tt0185937/reviews?ref_=tt_ql_3',
}

# %%
# This function is to grab text from the URL: grab_text_from_url
def grab_text_from_url(url):
    return requests.get(url).text
text = get_text_url(review_home_url['The Exorcist'])

# %%
# This function points to the links within the HTML
def get_all_links_from_html(html):
    tags = BeautifulSoup(html, 'html.parser', parse_only=SoupStrainer('a', href=True))
    urls = [str(tag.attrs['href']) for tag in tags]
    return urls
all_links = get_all_html_links(text)

# %%
# This defintion sets the URL template and allows the unique urls to be grabbed after the root url
def get_review_urls_from_links(links):
    url_template = 'https://www.imdb.com{}'
   
    return [url_template.format(link) for link in links]

urls = get_review_links(all_links);

# %%
# This defines the relevent part of the link by calling our review section to point to HTML post the root 'review'
def relevent_link(link):
    if '/review/' in link:
        return True
    return False
def get_relevent_links(links):
    relevent_links = filter(relevent_link, all_links)
    unique_relevent_links = set(relevent_links)
    return list(unique_relevent_links)
relevent_urls = get_relevent_links(urls)
len(relevent_urls)
# Out:
# 25

# %% [markdown]
# ##### HW 5: Question 2
# Extract noun phrase (NP) chunks from your reviews using the following procedure:
#
# a. In Python, use BeautifulSoup to grab the main review text from each link.

# %%
# Grabbing reviews rfom sites
def strain_content(name, attrs):
    if name == 'div' and dict(attrs).get('class', None) == 'content':
        return True
    return False
def clean_review_text(text):
    return re.split('\\n\\n\s+\d+ out of \d+', text)[0]
def get_review_from_url(url):
    html = grab_text_from_url(url)
    tags = BeautifulSoup(html, 'html.parser', parse_only=SoupStrainer(strain_content))
    review = clean_review_text(tags.text)
    return review

# %%
# Grabbing reviews rfom sites
def get_review_from_site(url):
    reviews = []

    reviews_home_text = grab_text_from_url(url)
    all_links = get_all_links_from_html(reviews_home_text)
    relevent_links = get_relevent_links(all_links)

    review_urls = get_review_urls_from_links(relevent_links)
    for url in review_urls:
        reviews.append(get_review_from_url(url))
        # break
    return reviews

# %%
# Locating the review sectiosn from the sites 
def get_reviews_from_all_sites():
    all_reviews = []
    review_titles = review_home_urls.keys()
    for title in review_titles:
        review_home_url = review_home_urls[title]
        all_reviews = all_reviews + get_review_from_site(review_home_url)
    return all_reviews

# %%
# The defintions for Part of Speech tagging
def pos_tagging_for_review(sentence):
    cleaned_review = sentence.lower()
    tokenized_review = word_tokenize(cleaned_review)
    return pos_tag(tokenized_review)
def get_chunking_for_sentence(sentence):
    tagged_sentence = pos_tagging_for_review(sentence)

    grammar = "NP: {<DT>?<JJ>*<NN>}"

    cp = nltk.RegexpParser(grammar)
    result = cp.parse(tagged_sentence)
    return result

def get_chunking_for_review(review):
    sentences = sent_tokenize(review)
    result = [get_chunking_for_sentence(sentence) for sentence in sentences]
    return result

# %% [markdown]
# b. Next run each review text through a tokenizer, and then try to NP-chunk it with a shallow parser.

# %%
# This is the funtion for chunking the reviews
def get_chunking_for_reviews(reviews):
    return [get_chunking_for_review(review) for review in reviews]

# %%
# Function for identifying noun phrases for chunking
def get_NP_for_review(review):
    main_trees = get_chunking_for_review(review)
    subtrees = []
    for main_tree in main_trees:
        for subtree in main_tree.subtrees():
            if subtree.label() == 'NP':
                subtrees.append(subtree)
    return subtrees[1:]

# %%
# Returning those noun phrases
def get_NP_for_reviews(reviews):
    return [get_NP_for_review(review) for review in reviews]

# %%
# Grabbign reviews and placing them in one place
all_reviews = get_reviews_from_all_sites()

# %%
# Quick view of all reivews
print(len(all_reviews))
# Out:
# 150

# %% [markdown]
# c. You probably will have too many unknown words, owing to proper names of characters, actors, and so on that are not in your working dictionary. Make sure the main names that are relevant to the movies in your collection of reviews are added to the working lexicon, and then run the NP chunker again.

# %%
noun_phrases_reviews = get_NP_for_reviews(all_reviews)

# %%
# Grabbing noun phrases w/ 4 word range
for noun_phrases in noun_phrases_reviews[0:4]:
    for i in range(4):
        print(noun_phrases[i])
    print()
# Out:
# (NP a/DT masterpiece/NN)
# (NP great/JJ cinematography/NN)
# (NP the/DT atmosphere/NN)
# (NP a/DT superb/JJ screenplay/NN)
#
# (NP everything/NN)
# (NP regan/NN)
# (NP linda/JJ blair/NN)
# (NP jason/JJ miller/NN)
#
# (NP the/DT dark/NN)
# (NP the/DT evil/NN)
# (NP a/DT mysterious/JJ presence/NN)
# (NP death/NN)
#
# (NP the/DT hysteria/NN)
# (NP mystique/NN)
# (NP the/DT exorcist/NN)
# (NP genius.never/NN)

# %% [markdown]
# #### HW 5: Question 3
#
# Output all the chunks in a single list for each review, and submit that output for this assignment. Also submit a brief written summary of what you did (describe your selection of genre, your source of reviews, how many you collected, and by what means).
#
# In order to collect movies and their reviewes I sourced reviews from the reviews pages of the top 6 horror movies of all time. I sourced the reviews from IMDB.com, one of the most proliferent movie review pages of all time. I collected and sourced the movies parsing HTML out of URL with the tool beautifulsoup in Python. I used NLTK to word chunk and identify *noun phrases* for review.

# %%
noun_phrases_reviews
# Out:
# [[Tree('NP', [('a', 'DT'), ('masterpiece', 'NN')]),
#   Tree('NP', [('great', 'JJ'), ('cinematography', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('atmosphere', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('superb', 'JJ'), ('screenplay', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('dialog', 'NN')]),
#   Tree('NP', [('plenty', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('linda', 'NN')]),
#   Tree('NP', [('blair', 'NN')]),
#   Tree('NP', [('burstyn', 'NN')]),
#   Tree('NP', [('jason', 'NN')]),
#   Tree('NP', [('miller', 'NN')]),
#   Tree('NP', [('max', 'JJ'), ('von', 'NN')]),
#   Tree('NP', [('sydow', 'NN')]),
#   Tree('NP', [('i', 'JJ'), ('pressure', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('re-edited', 'JJ'), ('one', 'NN')]),
#   Tree('NP', [('trust', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('remake', 'NN')]),
#   Tree('NP', [('editing', 'NN')]),
#   Tree('NP', [('sound', 'NN')]),
#   Tree('NP', [('picture', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('new', 'JJ'), ('footage', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('quality.if', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('kind', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('good', 'JJ'), ('drama', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('head-spinning', 'JJ'), ('performance', 'NN')]),
#   Tree('NP', [('linda', 'JJ'), ('blair', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('little', 'JJ'), ('innocent', 'JJ'), ('child', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('horrid', 'JJ'), ('demon', 'NN')]),
#   Tree('NP', [('ellen', 'JJ'), ('burstyn', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('great', 'JJ'), ('performance', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('mother', 'NN')]),
#   Tree('NP', [('shock', 'NN')]),
#   Tree('NP', [('worry', 'NN')]),
#   Tree('NP', [('daughter', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('acting', 'NN')]),
#   Tree('NP', [('cinematic', 'JJ'), ('experience', 'NN')]),
#   Tree('NP', [('overall', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('satisfying', 'JJ'), ('amount', 'NN')]),
#   Tree('NP', [('good', 'JJ'), ('dialog', 'NN')]),
#   Tree('NP', [('gut-wrenching', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('gritty', 'JJ'), ('drama', 'NN')]),
#   Tree('NP', [('awe-inspiring', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('memorable', 'JJ'), ('film.4', 'NN')])],
#  [Tree('NP', [('everything', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('linda', 'JJ'), ('blair', 'NN')]),
#   Tree('NP', [('jason', 'JJ'), ('miller', 'NN')]),
#   Tree('NP', [('nothing', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('incredible', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('spot', 'NN')]),
#   Tree('NP', [('grossness', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('lol', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('dark', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('evil', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('mysterious', 'JJ'), ('presence', 'NN')]),
#   Tree('NP', [('death', 'NN')]),
#   Tree('NP', [('fact', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('unknown', 'JJ'), ('force', 'NN')]),
#   Tree('NP', [('presence', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('life', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('dawn', 'NN')]),
#   Tree('NP', [('humanity', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('unconscious', 'JJ'), ('way', 'NN')]),
#   Tree('NP', [('mortal', 'JJ'), ('nature', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('awareness', 'NN')]),
#   Tree('NP', [('fear', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fear', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('genius', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('horror', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('masterpiece', 'NN')]),
#   Tree('NP', [('realism', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('atmosphere', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('fearsome', 'NN')]),
#   Tree('NP', [('gloomy', 'JJ'), ('ambiance', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('place', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('everything', 'NN')]),
#   Tree('NP', [('such', 'JJ'), ('confidence', 'NN')]),
#   Tree('NP', [('meticulousness', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('cinematic', 'JJ'), ('trick', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('director', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('hour', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('set-up', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('intelligence', 'NN')]),
#   Tree('NP', [('william', 'JJ'), ('friedkin', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('realistic', 'JJ'), ('masterpiece', 'NN')]),
#   Tree('NP', [('picture', 'NN')]),
#   Tree('NP', [('winner', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('french', 'JJ'), ('connection', 'NN')]),
#   Tree('NP', [('enough', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('daily', 'JJ'), ('life', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('pivotal', 'JJ'), ('point', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('direction', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('writing', 'NN')]),
#   Tree('NP', [('subtlety', 'NN')]),
#   Tree('NP', [('work', 'NN')]),
#   Tree('NP', [('nothing', 'NN')]),
#   Tree('NP', [('guard', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('evil', 'JJ'), ('presence', 'NN')]),
#   Tree('NP', [('it.this', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('old', 'JJ'), ('cinematic', 'JJ'), ('device', 'NN')]),
#   Tree('NP', [('enough', 'JJ'), ('money', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('scare', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('suggestion', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('presence', 'NN')]),
#   Tree('NP', [('explicit', 'JJ'), ('depiction', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('villain', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('shark', 'NN')]),
#   Tree('NP', [('jaws', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('slight', 'JJ'), ('difference', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('body', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('poor', 'JJ'), ('little', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('linda', 'NN')]),
#   Tree('NP', [('blair', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('macneil', 'NN')]),
#   Tree('NP', [('heart', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('evil', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('pure', 'JJ'), ('little', 'JJ'), ('soul', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('tragedy', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('torment', 'NN')]),
#   Tree('NP', [('mother', 'NN')]),
#   Tree('NP', [('chris', 'NN')]),
#   Tree('NP', [('burstyn', 'NN')]),
#   Tree('NP', [('helpless', 'JJ'), ('woman', 'NN')]),
#   Tree('NP', [('little', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fascinating', 'JJ'), ('aspect', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('drama', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('thrilling', 'NN')]),
#   Tree('NP', [('mystery', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('mystery', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('lieutenant', 'JJ'), ('detective', 'JJ'), ('kinderman', 'NN')]),
#   Tree('NP', [('lee', 'JJ'), ('j.', 'NN')]),
#   Tree('NP', [('cobb', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('one', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('bridge', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('priests.so', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('beginning', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('sooner', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('exorcism', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('title', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('set-up', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('damien', 'NN')]),
#   Tree('NP', [('jason', 'NN')]),
#   Tree('NP', [('miller', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('iconic', 'JJ'), ('father', 'NN')]),
#   Tree('NP', [('merryl', 'NN')]),
#   Tree('NP', [('sydow', 'NN')]),
#   Tree('NP', [('patience', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcism', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('build-up', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('climax', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('impatience', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('director', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('eagerness', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('big', 'JJ'), ('impatience', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('magnificent', 'NN')]),
#   Tree('NP', [('ambitious', 'JJ'), ('project', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('masterpiece', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('patience', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('iconic', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('masterpiece', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('few', 'JJ'), ('horrifying', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('set-up', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('climax', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('level', 'NN')]),
#   Tree('NP', [('cinematography', 'NN')]),
#   Tree('NP', [('course', 'NN')]),
#   Tree('NP', [('timing', 'NN')]),
#   Tree('NP', [('total', 'JJ'), ('symbiosis', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('realism', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('hollywood', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('american', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('institute', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('list', 'NN')]),
#   Tree('NP', [('horrifying', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('everything', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('dazzling', 'NN')]),
#   Tree('NP', [('cinematography', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('iconic', 'JJ'), ('shot', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('merryl', 'NN')]),
#   Tree('NP', [('shadowy', 'JJ'), ('silhouette', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('mist', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('unforgettable', 'JJ'), ('villain', 'NN')]),
#   Tree('NP', [('course', 'NN')]),
#   Tree('NP', [('shocking', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('make-up', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('genre', 'NN')]),
#   Tree('NP', [('realism', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('realism', 'NN')]),
#   Tree('NP', [('nothing', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('genius', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('script', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('masterful', 'JJ'), ('direction', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('greatness', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('last', 'JJ'), ('act', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('simple', 'JJ'), ('act', 'NN')]),
#   Tree('NP', [('watching', 'NN')]),
#   Tree('NP', [('experiences.and', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('i', 'NN')]),
#   Tree('NP', [('night', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('must-see', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('hysteria', 'NN')]),
#   Tree('NP', [('mystique', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('genius.never', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('shock', 'NN')]),
#   Tree('NP', [('terror', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('horror', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('moving', 'NN')]),
#   Tree('NP', [('drama', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('realistic', 'JJ'), ('look', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('young', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('modern', 'JJ'), ('america', 'NN')]),
#   Tree('NP', [('william', 'NN')]),
#   Tree('NP', [('peter', 'NN')]),
#   Tree('NP', [('blatty', 'NN')]),
#   Tree('NP', [('script', 'NN')]),
#   Tree('NP', [('depth', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('mystery', 'NN')]),
#   Tree('NP', [('faith', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('deal', 'NN')]),
#   Tree('NP', [('insane', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('god', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('course', 'NN')]),
#   Tree('NP', [('innocent', 'JJ'), ('young', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('cross', 'NN')]),
#   Tree('NP', [('masturbating', 'NN')]),
#   Tree('NP', [('head', 'NN')]),
#   Tree('NP', [('spinning', 'NN')]),
#   Tree('NP', [('creature', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('successful', 'JJ'), ('actress', 'NN')]),
#   Tree('NP', [('overcome', 'JJ'), ('skepticism', 'NN')]),
#   Tree('NP', [('daughter', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('brilliant', 'JJ'), ('psychiatrist', 'NN')]),
#   Tree('NP', [('struggle', 'NN')]),
#   Tree('NP', [('devotion', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('priest.friedkin', 'NN')]),
#   Tree('NP', [('direction', 'NN')]),
#   Tree('NP', [('light', 'NN')]),
#   Tree('NP', [('dark', 'NN')]),
#   Tree('NP', [('color', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('jason', 'NN')]),
#   Tree('NP', [('miller', 'NN')]),
#   Tree('NP', [('damien', 'NN')]),
#   Tree('NP', [('first', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('role', 'NN')]),
#   Tree('NP', [('max', 'NN')]),
#   Tree('NP', [('von', 'NN')]),
#   Tree('NP', [('sydow', 'NN')]),
#   Tree('NP', [('lee', 'NN')]),
#   Tree('NP', [('j.', 'NN')]),
#   Tree('NP', [('cobb', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('experienced', 'JJ'), ('priest', 'NN')]),
#   Tree('NP', [('impending', 'JJ'), ('doom', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('detective', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('sinister', 'NN')]),
#   Tree('NP', [('work', 'NN')]),
#   Tree('NP', [('ellen', 'JJ'), ('burstyn', 'NN')]),
#   Tree('NP', [('honest', 'JJ'), ('performance', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('grief', 'NN')]),
#   Tree('NP', [('stricken', 'JJ'), ('woman', 'NN')]),
#   Tree('NP', [('daughter', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('12-year-old', 'JJ'), ('linda', 'NN')]),
#   Tree('NP', [('blair', 'NN')]),
#   Tree('NP', [('convincing', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('range', 'NN')]),
#   Tree('NP', [('emotion', 'NN')]),
#   Tree('NP', [('connection', 'NN')]),
#   Tree('NP', [('oscar', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('mystery', 'NN')]),
#   Tree('NP', [('faith', 'NN')]),
#   Tree('NP', [('raw', 'JJ'), ('form', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('battle', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('incomparable', 'JJ'), ('masterpiece', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('aid', 'NN')]),
#   Tree('NP', [('story', 'NN')]),
#   Tree('NP', [('piece', 'NN')]),
#   Tree('NP', [('work', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('end', 'NN')])],
#  [Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('100th', 'JJ'), ('listen', 'NN')]),
#   Tree('NP', [('oldfield', 'NN')]),
#   Tree('NP', [('masterpiece', 'NN')]),
#   Tree('NP', [('48-minute', 'JJ'), ('album', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('4-minute', 'JJ'), ('edit', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('soundtrack', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('gory', 'NN')]),
#   Tree('NP', [('gruesome', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('atmosphere', 'NN')]),
#   Tree('NP', [('intelligent', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('masterful', 'JJ'), ('filmmaking', 'NN')]),
#   Tree('NP', [('genuine', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('beautiful', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('faith', 'NN')]),
#   Tree('NP', [('evil', 'NN')]),
#   Tree('NP', [('scheme', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('unusual', 'JJ'), ('way', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('paragraphs', 'NN')]),
#   Tree('NP', [('suffice', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('build', 'NN')]),
#   Tree('NP', [('tension', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('glorious', 'JJ'), ('resolution', 'NN')]),
#   Tree('NP', [('good', 'JJ'), ('defeat', 'NN')]),
#   Tree('NP', [('movie', 'NN')])],
#  [Tree('NP', [('a', 'DT'), ('mother', 'NN')]),
#   Tree('NP', [('ellen', 'JJ'), ('burstyn', 'NN')]),
#   Tree('NP', [('daughter', 'NN')]),
#   Tree('NP', [('linda', 'JJ'), ('blair', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('latter', 'NN')]),
#   Tree('NP', [('jason', 'JJ'), ('miller', 'NN')]),
#   Tree('NP', [('sidow', 'NN')]),
#   Tree('NP', [('attempt', 'NN')]),
#   Tree('NP', [('regan', 'JJ'), ('macneil', 'NN')]),
#   Tree('NP', [('possession', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('devil', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('police', 'NN')]),
#   Tree('NP', [('inspector', 'NN')]),
#   Tree('NP', [('lee', 'JJ'), ('j.', 'NN')]),
#   Tree('NP', [('cobb', 'NN')]),
#   Tree('NP', [('unravel', 'JJ'), ('mystery', 'NN')]),
#   Tree('NP', [('demon', 'NN')]),
#   Tree('NP', [('living', 'NN')]),
#   Tree('NP', [('story', 'NN')]),
#   Tree('NP', [('true', 'JJ'), ('flick', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('eerie', 'JJ'), ('finale', 'NN')]),
#   Tree('NP', [('top-notch', 'JJ'), ('picture', 'NN')]),
#   Tree('NP', [('acting', 'NN')]),
#   Tree('NP', [('tight', 'JJ'), ('pacing', 'NN')]),
#   Tree('NP', [('edition', 'NN')]),
#   Tree('NP', [('dick', 'NN')]),
#   Tree('NP', [('smith', 'NN')]),
#   Tree('NP', [('creepy', 'NN')]),
#   Tree('NP', [('acting', 'NN')]),
#   Tree('NP', [('linda', 'NN')]),
#   Tree('NP', [('blair', 'NN')]),
#   Tree('NP', [('death', 'NN')]),
#   Tree('NP', [('linda', 'JJ'), ('blair', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('satan', 'NN')]),
#   Tree('NP', [('warner', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('release', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('first', 'JJ'), ('day', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcism', 'NN')]),
#   Tree('NP', [('sequence', 'NN')]),
#   Tree('NP', [('blair', 'NN')]),
#   Tree('NP', [('delivery', 'NN')]),
#   Tree('NP', [('foul-mouthed', 'JJ'), ('dialogue', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('gentlemanly', 'JJ'), ('max', 'NN')]),
#   Tree('NP', [('von', 'NN')]),
#   Tree('NP', [('sydow', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('script', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('acting', 'JJ'), ('excellent', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('direction', 'NN')]),
#   Tree('NP', [('william', 'JJ'), ('friedkin', 'JJ'), ('plenty', 'NN')]),
#   Tree('NP', [('good', 'JJ'), ('pace', 'NN')]),
#   Tree('NP', [('conviction', 'NN')]),
#   Tree('NP', [('enjoyable', 'JJ'), ('secondary', 'JJ'), ('cast', 'NN')]),
#   Tree('NP', [('lee', 'JJ'), ('j', 'NN')]),
#   Tree('NP', [('cobb', 'NN')]),
#   Tree('NP', [('winn', 'NN')]),
#   Tree('NP', [('jack', 'NN')]),
#   Tree('NP', [('mcgowran', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('legend', 'NN')]),
#   Tree('NP', [('exorcist', 'NN')]),
#   Tree('NP', [('curse', 'NN')]),
#   Tree('NP', [('dark', 'JJ'), ('cinematography', 'NN')]),
#   Tree('NP', [('sinister', 'NN')]),
#   Tree('NP', [('mysterious', 'JJ'), ('atmosphere', 'NN')]),
#   Tree('NP', [('owen', 'JJ'), ('roitzman', 'NN')]),
#   Tree('NP', [('musical', 'JJ'), ('score', 'NN')]),
#   Tree('NP', [('mike', 'JJ'), ('oldfield', 'NN')]),
#   Tree('NP', [('soundtrack', 'NN')]),
#   Tree('NP', [('¨tubular', 'JJ'), ('bells¨', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('tale', 'NN')]),
#   Tree('NP', [('graphic', 'JJ'), ('violence', 'NN')]),
#   Tree('NP', [('profanity', 'NN')]),
#   Tree('NP', [('gore', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('special', 'JJ'), ('edition', 'NN')]),
#   Tree('NP', [('director', 'NN')]),
#   Tree('NP', [('additional', 'JJ'), ('footage', 'NN')]),
#   Tree('NP', [('¨the', 'NN')]),
#   Tree('NP', [('heretic¨', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('borman', 'NN')]),
#   Tree('NP', [('richard', 'JJ'), ('burton', 'NN')]),
#   Tree('NP', [('exorcist', 'NN')]),
#   Tree('NP', [('iii¨', 'NN')]),
#   Tree('NP', [('william', 'NN')]),
#   Tree('NP', [('peter', 'NN')]),
#   Tree('NP', [('blatty', 'NN')]),
#   Tree('NP', [('george', 'NN')]),
#   Tree('NP', [('scott', 'NN')]),
#   Tree('NP', [('brad', 'NN')]),
#   Tree('NP', [('dourif', 'NN')]),
#   Tree('NP', [('nicol', 'JJ'), ('williamson', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('young', 'JJ'), ('father', 'NN')]),
#   Tree('NP', [('merrin', 'NN')]),
#   Tree('NP', [('stellan', 'JJ'), ('skarsgard', 'NN')]),
#   Tree('NP', [('set', 'NN')]),
#   Tree('NP', [('africa', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('schrader', 'NN')]),
#   Tree('NP', [('renny', 'JJ'), ('harlin', 'NN')])],
#  [Tree('NP', [('no', 'DT'), ('pun', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('innate', 'NN')]),
#   Tree('NP', [('feeling', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('realm', 'NN')]),
#   Tree('NP', [('dogma', 'NN')]),
#   Tree('NP', [('conventional', 'JJ'), ('logic', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('sixth', 'JJ'), ('grade', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('senseless', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('idea', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('devil', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('delicate', 'JJ'), ('core', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('soul', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('young', 'JJ'), ('age', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('speechless', 'NN')]),
#   Tree('NP', [('william', 'NN')]),
#   Tree('NP', [('friedkin', 'NN')]),
#   Tree('NP', [('transformation', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('opinion', 'NN')]),
#   Tree('NP', [('dick', 'NN')]),
#   Tree('NP', [('smith', 'NN')]),
#   Tree('NP', [('contrast', 'NN')]),
#   Tree('NP', [('today', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('industry', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('test', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('acting', 'NN')]),
#   Tree('NP', [('lee', 'JJ'), ('j.', 'NN')]),
#   Tree('NP', [('cobb', 'NN')]),
#   Tree('NP', [('jason', 'NN')]),
#   Tree('NP', [('miller', 'NN')]),
#   Tree('NP', [('burstyn', 'NN')]),
#   Tree('NP', [('max', 'NN')]),
#   Tree('NP', [('sydow', 'NN')]),
#   Tree('NP', [('limited', 'JJ'), ('appearance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('piece', 'NN')]),
#   Tree('NP', [('friedkin', 'NN')]),
#   Tree('NP', [('slice-of-life', 'JJ'), ('direction', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('essence', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fear-factor', 'NN')]),
#   Tree('NP', [('subtle', 'JJ'), ('fashion', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('viewer', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('lending', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('creepiness', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('minimal', 'JJ'), ('musical', 'JJ'), ('score', 'NN')]),
#   Tree('NP', [('mike', 'JJ'), ('oldfield', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('georgetown', 'JJ'), ('street', 'NN')]),
#   Tree('NP', [('autumn', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('wind', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('palpability', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('young', 'JJ'), ('linda', 'NN')]),
#   Tree('NP', [('blair', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('notion', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('earth', 'NN')]),
#   Tree('NP', [('human', 'JJ'), ('form', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('couple', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('subject', 'JJ'), ('matter', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('new', 'JJ'), ('version', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('last', 'JJ'), ('nail', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('proverbial', 'JJ'), ('coffin', 'NN')]),
#   Tree('NP', [('effectiveness', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('linda', 'NN')]),
#   Tree('NP', [('blair', 'NN')]),
#   Tree('NP', [('cute', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('macneil', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('beast', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('age', 'NN')]),
#   Tree('NP', [('fourteen', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('put', 'NN')]),
#   Tree('NP', [('age', 'NN')]),
#   Tree('NP', [('forty-three', 'JJ'), ('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('difficult', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('great', 'JJ'), ('job', 'NN')]),
#   Tree('NP', [('mr.', 'JJ'), ('friedkin', 'NN')]),
#   Tree('NP', [('crew', 'NN')])],
#  [Tree('NP', [('all', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('disagree', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('former', 'JJ'), ('group', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('cave', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('past', 'JJ'), ('twenty', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('pre-pubescent', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('linda', 'JJ'), ('blair', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('demon', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('devil', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('day', 'NN')]),
#   Tree('NP', [('age', 'NN')]),
#   Tree('NP', [('schlock', 'NN')]),
#   Tree('NP', [('horror', 'NN')]),
#   Tree('NP', [('want', 'NN')]),
#   Tree('NP', [('term', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('big', 'JJ'), ('wig', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('quest', 'NN')]),
#   Tree('NP', [('cash', 'NN')]),
#   Tree('NP', [('teenage', 'NN')]),
#   Tree('NP', [('trend', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('premise', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('road', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('supposition', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('rest.the', 'NN')]),
#   Tree('NP', [('dread', 'NN')]),
#   Tree('NP', [('fear', 'NN')]),
#   Tree('NP', [('sydow', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('merrin', 'NN')]),
#   Tree('NP', [('disturbing', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('archaeological', 'JJ'), ('dig', 'NN')]),
#   Tree('NP', [('northern', 'JJ'), ('iraq.we', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('setting', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('real', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('georgetown', 'JJ'), ('home', 'NN')]),
#   Tree('NP', [('chris', 'NN')]),
#   Tree('NP', [('macneil', 'NN')]),
#   Tree('NP', [('ellen', 'JJ'), ('burstyn', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('successful', 'JJ'), ('divorcée', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('actress', 'NN')]),
#   Tree('NP', [('living', 'NN')]),
#   Tree('NP', [('daughter', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('regan', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('close', 'NN')]),
#   Tree('NP', [('loving', 'NN')]),
#   Tree('NP', [('relationship', 'NN')]),
#   Tree('NP', [('mother', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('strained', 'JJ'), ('relationship', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('innocent', 'JJ'), ('demeanour', 'NN')]),
#   Tree('NP', [('narrow', 'JJ'), ('vocabulary', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('normal', 'JJ'), ('young', 'JJ'), ('girl.the', 'NN')]),
#   Tree('NP', [('gradual', 'JJ'), ('change', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('personality', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('emergence', 'NN')]),
#   Tree('NP', [('captain', 'NN')]),
#   Tree('NP', [('howdy', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('imaginary', 'JJ'), ('friend', 'NN')]),
#   Tree('NP', [('chris', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('bottom', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('behaviour', 'NN')]),
#   Tree('NP', [('spine', 'NN')]),
#   Tree('NP', [('chilling', 'NN')]),
#   Tree('NP', [('sudden', 'JJ'), ('maturity', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('help', 'NN')]),
#   Tree('NP', [('world', 'NN')]),
#   Tree('NP', [('weary', 'JJ'), ('jesuit', 'NN')]),
#   Tree('NP', [('psychiatrist', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('jason', 'JJ'), ('miller', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('exorcism.by', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('semblance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('innocent', 'JJ'), ('young', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('faith', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('exorcism', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('permission', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('catholic', 'JJ'), ('church', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('condition', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('help', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('experienced', 'JJ'), ('father', 'NN')]),
#   Tree('NP', [('merrin.merrin', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('knight', 'NN')]),
#   Tree('NP', [('armour', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('ultimate', 'JJ'), ('showdown', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('great', 'JJ'), ('screenplay', 'NN')]),
#   Tree('NP', [('william', 'NN')]),
#   Tree('NP', [('peter', 'NN')]),
#   Tree('NP', [('blatty', 'NN')]),
#   Tree('NP', [('book', 'NN')]),
#   Tree('NP', [('william', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('ellen', 'JJ'), ('burstyn', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('traumatised', 'JJ'), ('mother', 'NN')]),
#   Tree('NP', [('make', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('classic', 'JJ'), ('piece', 'NN')]),
#   Tree('NP', [('horror', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('test', 'NN')]),
#   Tree('NP', [('time', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('kind', 'NN')]),
#   Tree('NP', [('80-minute', 'JJ'), ('splatter', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('bad', 'JJ'), ('guy', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('monster', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('drama', 'NN')]),
#   Tree('NP', [('slaughter', 'NN')]),
#   Tree('NP', [('class', 'NN')]),
#   Tree('NP', [('purpose', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('audience', 'NN')]),
#   Tree('NP', [('humankind', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('message', 'NN')]),
#   Tree('NP', [('hope', 'NN')]),
#   Tree('NP', [('self-sacrifice', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('smart', 'NN')]),
#   Tree('NP', [('clever', 'NN')]),
#   Tree('NP', [('meaningful', 'JJ'), ('horror-drama', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('hand', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('tension', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('mother', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cusp', 'NN')]),
#   Tree('NP', [('tragedy', 'NN')]),
#   Tree('NP', [('sydow', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('ray', 'NN')]),
#   Tree('NP', [('light', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('sadness', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('defeated', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('blair', 'NN')]),
#   Tree('NP', [('young', 'JJ'), ('age.once', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')])],
#  [Tree('NP', [('anxiety', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('first', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('anxiety', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('lot', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('*should*', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('top', 'NN')]),
#   Tree('NP', [('it.i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('exposure', 'NN')]),
#   Tree('NP', [('many', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('genre', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('die-hard', 'JJ'), ('fan', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie.first', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('reason', 'NN')]),
#   Tree('NP', [('fright', 'JJ'), ('factor', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('\x96', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('\x96', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('hollywood', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('credits-to-credits', 'JJ'), ('montage', 'NN')]),
#   Tree('NP', [('scary', 'JJ'), ('imagery', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('mere', 'JJ'), ('scenario', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('plot', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('long', 'JJ'), ('dark', 'NN')]),
#   Tree('NP', [('corridor', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('darkness', 'NN')]),
#   Tree('NP', [('attack', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('false', 'JJ'), ('scare', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('cat', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('cheap', 'JJ'), ('gimmicky', 'NN')]),
#   Tree('NP', [('scenario', 'NN')]),
#   Tree('NP', [('amount', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('rest', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('world', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('killer/monster/ghost/whatever', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('loose.the', 'JJ'), ('exorcist', 'NN')]),
#   Tree('NP', [('slow', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('full', 'JJ'), ('blown', 'NN')]),
#   Tree('NP', [('plot', 'NN')]),
#   Tree('NP', [('arcs', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('original', 'JJ'), ('ambition', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('world', 'NN')]),
#   Tree('NP', [('imagery', 'NN')]),
#   Tree('NP', [('cinema', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('audience', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('silver', 'NN')]),
#   Tree('NP', [('screen', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('major', 'JJ'), ('studio', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('success', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('countless', 'JJ'), ('imitation', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('ambition', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('story.everyone', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('pea', 'NN')]),
#   Tree('NP', [('soup', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('head', 'NN')]),
#   Tree('NP', [('spinning', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('demon', 'NN')]),
#   Tree('NP', [('mouth', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('infamous', 'JJ'), ('cut', 'NN')]),
#   Tree('NP', [('spider', 'NN')]),
#   Tree('NP', [('walk', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('one', 'NN')]),
#   Tree('NP', [('\x96', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('setup', 'NN')]),
#   Tree('NP', [('iraq', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('lancaster', 'NN')]),
#   Tree('NP', [('merrin', 'NN')]),
#   Tree('NP', [('final', 'JJ'), ('showdown', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('epic', 'JJ'), ('feel', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('transition', 'NN')]),
#   Tree('NP', [('chris', 'NN')]),
#   Tree('NP', [('macneil', 'NN')]),
#   Tree('NP', [('campus', 'NN')]),
#   Tree('NP', [('reminiscent', 'NN')]),
#   Tree('NP', [('alfred', 'JJ'), ('hitchcock', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('mother', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('close', 'NN')]),
#   Tree('NP', [('relationship', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('drink', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('fellow', 'JJ'), ('priest', 'NN')]),
#   Tree('NP', [('faith.and', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('possibility', 'NN')]),
#   Tree('NP', [('possession', 'NN')]),
#   Tree('NP', [('exorcism', 'NN')]),
#   Tree('NP', [('final', 'JJ'), ('solution', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('fact', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('possibility', 'NN')]),
#   Tree('NP', [('exorcism', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('delight', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('hospital', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('priceless', 'JJ'), ('moment', 'NN')]),
#   Tree('NP', [('chris', 'NN')]),
#   Tree('NP', [('macneil', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('exorcism', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('church', 'NN')]),
#   Tree('NP', [('mind.the', 'NN')]),
#   Tree('NP', [('fact', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('temptation', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('acknowledgment', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('epic', 'NN')]),
#   Tree('NP', [('good', 'JJ'), ('versus', 'NN')]),
#   Tree('NP', [('evil', 'NN')]),
#   Tree('NP', [('god', 'JJ'), ('versus', 'NN')]),
#   Tree('NP', [('satan', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('demon', 'NN')]),
#   Tree('NP', [('feel', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('possibility', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('audience', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('only', 'JJ'), ('hope', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('glorious', 'JJ'), ('fanfare', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('merrin', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('sunny', 'JJ'), ('garden', 'NN')]),
#   Tree('NP', [('path', 'NN')]),
#   Tree('NP', [('envelope', 'NN')]),
#   Tree('NP', [('imagery', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('ominous', 'JJ'), ('foggy', 'NN')]),
#   Tree('NP', [('night', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('taxi', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('macneil', 'JJ'), ('place', 'NN')]),
#   Tree('NP', [('georgetown', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('haunting', 'NN')]),
#   Tree('NP', [('imagery', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cover', 'NN')]),
#   Tree('NP', [('art', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('merrin', 'NN')]),
#   Tree('NP', [('imagery', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('dialogue', 'NN')]),
#   Tree('NP', [('karras', 'NN')]),
#   Tree('NP', [('merrin', 'NN')]),
#   Tree('NP', [('one', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('acting', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('beautiful', 'JJ'), ('cinematography', 'NN')]),
#   Tree('NP', [('brilliant', 'JJ'), ('makeup', 'NN')]),
#   Tree('NP', [('\x96', 'NN')]),
#   Tree('NP', [('fan', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('inch', 'NN')]),
#   Tree('NP', [('everything', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('type', 'NN')]),
#   Tree('NP', [('person', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('specific', 'JJ'), ('imagery', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('deep', 'JJ'), ('enough', 'JJ'), ('impression', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('wonderful', 'JJ'), ('craftsmanship', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('expectations.when', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('grudge', 'NN')]),
#   Tree('NP', [('skeleton', 'NN')]),
#   Tree('NP', [('key', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')])],
#  [Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('blu-ray', 'NN')]),
#   Tree('NP', [('favourite', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('top', 'JJ'), ('ten', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('masterpiece', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('making', 'NN')]),
#   Tree('NP', [('beautiful', 'JJ'), ('photography', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('great', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('today', 'NN')])],
#  [Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('good', 'JJ'), ('reason', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('mould', 'NN')]),
#   Tree('NP', [('everything', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('standard', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('genre', 'NN')]),
#   Tree('NP', [('place', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('history', 'NN')]),
#   Tree('NP', [('forever.the', 'NN')]),
#   Tree('NP', [('sheer', 'NN')]),
#   Tree('NP', [('terror', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('year', 'NN')]),
#   Tree('NP', [('release', 'NN')]),
#   Tree('NP', [('today', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('effect', 'NN')]),
#   Tree('NP', [('audience', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('advice', 'NN')]),
#   Tree('NP', [('approach', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('open', 'JJ'), ('mind', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('only', 'JJ'), ('way', 'NN')]),
#   Tree('NP', [('time', 'NN')])],
#  [Tree('NP', [('version', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('other', 'JJ'), ('version', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('screen', 'NN')]),
#   Tree('NP', [('william', 'NN')]),
#   Tree('NP', [('peter', 'NN')]),
#   Tree('NP', [('blatty', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('novel', 'NN')]),
#   Tree('NP', [('incident', 'JJ'), ('driven', 'JJ'), ('basis', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('history', 'NN')]),
#   Tree('NP', [('cinema', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('ingmar', 'JJ'), ('bergman', 'NN')]),
#   Tree('NP', [('bertolucci', 'NN')]),
#   Tree('NP', [('depressive', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('study', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('tango', 'NN')]),
#   Tree('NP', [('paris', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('crime', 'NN')]),
#   Tree('NP', [('story', 'NN')]),
#   Tree('NP', [('redford', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('sting', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('year', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('step', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('rest', 'NN')]),
#   Tree('NP', [('uniqueness', 'NN')]),
#   Tree('NP', [('genre', 'NN')]),
#   Tree('NP', [('renewal', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('first', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('demon', 'NN')]),
#   Tree('NP', [('content', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('demon', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('human', 'JJ'), ('level', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('idea', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('spirit', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('first', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('horror', 'NN')]),
#   Tree('NP', [('genre', 'NN')]),
#   Tree('NP', [('crime', 'NN')]),
#   Tree('NP', [('hitchcock', 'NN')]),
#   Tree('NP', [('crime', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('separate', 'JJ'), ('genre', 'NN')]),
#   Tree('NP', [('sound', 'NN')]),
#   Tree('NP', [('mixing', 'NN')]),
#   Tree('NP', [('course', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('perfect', 'JJ'), ('screenplay', 'NN')]),
#   Tree('NP', [('director', 'NN')]),
#   Tree('NP', [('friedkin', 'NN')]),
#   Tree('NP', [('producer', 'NN')]),
#   Tree('NP', [('blatty', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('novel-writer', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('idea', 'NN')]),
#   Tree('NP', [('creator', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('plot', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('development', 'NN')]),
#   Tree('NP', [('merrin', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('demon', 'NN')]),
#   Tree('NP', [('pazuzu', 'NN')]),
#   Tree('NP', [('iraq', 'NN')]),
#   Tree('NP', [('burstyn', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cure', 'NN')]),
#   Tree('NP', [('daughter', 'NN')]),
#   Tree('NP', [('disease', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('type', 'NN')]),
#   Tree('NP', [('doctor', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('rug', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('demon', 'NN')]),
#   Tree('NP', [('speech', 'NN')]),
#   Tree('NP', [('reverse', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('arriving', 'NN')]),
#   Tree('NP', [('merrin', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('editing', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film.the', 'NN')]),
#   Tree('NP', [('anniversary', 'JJ'), ('edition', 'NN')]),
#   Tree('NP', [('dvd', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('horror', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('version', 'NN')]),
#   Tree('NP', [('dvd', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('year', 'NN')]),
#   Tree('NP', [('version', 'NN')]),
#   Tree('NP', [('incident', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('missing', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('spider-walk', 'JJ'), ('scene', 'NN')]),
#   Tree('NP', [('sound', 'NN')]),
#   Tree('NP', [('mixing', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('demon', 'NN')]),
#   Tree('NP', [('voice', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('bbc', 'JJ'), ('documentary', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fear', 'NN')]),
#   Tree('NP', [('god', 'NN')])],
#  [Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('imbb', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('list', 'NN')]),
#   Tree('NP', [('rate', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('jump', 'NN')]),
#   Tree('NP', [('torture', 'NN')]),
#   Tree('NP', [('porn', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('modern', 'JJ'), ('era', 'NN')]),
#   Tree('NP', [('horror', 'NN')]),
#   Tree('NP', [('either', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('godfather', 'NN')]),
#   Tree('NP', [('genre', 'NN')]),
#   Tree('NP', [('absolute', 'JJ'), ('perfection', 'NN')])],
#  [Tree('NP', [('order', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('truly', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('terrifying', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('slasher', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('scary', 'JJ'), ('michael', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('normal', 'JJ'), ('house', 'NN')]),
#   Tree('NP', [('upstairs', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('little', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('devil', 'NN')]),
#   Tree('NP', [('faith', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('imagination', 'NN')]),
# ...
#   Tree('NP', [('faith', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('prospect', 'NN')]),
#   Tree('NP', [('satan', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('life', 'NN')]),
#   Tree('NP', [('eternal', 'JJ'), ('damnation', 'NN')]),
#   Tree('NP', [('uncomfortable', 'JJ'), ('prospect', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('blatty', 'NN')]),
#   Tree('NP', [('book', 'NN')]),
#   Tree('NP', [('screenplay', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('true', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('conflict', 'NN')]),
#   Tree('NP', [('pure', 'JJ'), ('evil', 'NN')]),
#   Tree('NP', [('pure', 'NN')]),
#   Tree('NP', [('innocence', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('average', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('story', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('eye', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('doubt', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('main', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('innocent', 'JJ'), ('young', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('blair', 'NN')]),
#   Tree('NP', [('satan', 'NN')]),
#   Tree('NP', [('conflict', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('mother', 'NN')]),
#   Tree('NP', [('chris', 'NN')]),
#   Tree('NP', [('mcneil', 'NN')]),
#   Tree('NP', [('ellen', 'JJ'), ('burstyn', 'NN')]),
#   Tree('NP', [('deeply', 'NN')]),
#   Tree('NP', [('daughter', 'NN')]),
#   Tree('NP', [('reproach', 'NN')]),
#   Tree('NP', [('scene', 'NN')]),
#   Tree('NP', [('reagan', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('regan', 'NN')]),
#   Tree('NP', [('birthday', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('phone', 'NN')]),
#   Tree('NP', [('battle', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('overseas', 'JJ'), ('operator', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('problem', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('phone', 'NN')]),
#   Tree('NP', [('call', 'NN')]),
#   Tree('NP', [('ear', 'JJ'), ('shot', 'NN')]),
#   Tree('NP', [('daughter', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('point', 'NN')]),
#   Tree('NP', [('home', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('aid', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('exorcism', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('daughter.father', 'NN')]),
#   Tree('NP', [('karras', 'NN')]),
#   Tree('NP', [('jason', 'JJ'), ('miller', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('priest', 'JJ'), ('torn', 'NN')]),
#   Tree('NP', [('conflict', 'NN')]),
#   Tree('NP', [('guilt', 'NN')]),
#   Tree('NP', [('mother', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('priesthood', 'NN')]),
#   Tree('NP', [('help', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('psychiatrist', 'NN')]),
#   Tree('NP', [('own', 'JJ'), ('faith', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('bishop', 'NN')]),
#   Tree('NP', [('case', 'NN')]),
#   Tree('NP', [('chris', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('power', 'NN')]),
#   Tree('NP', [('satan', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('living', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('manner', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('priest', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('health', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('child.jack', 'NN')]),
#   Tree('NP', [('mcgowran', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('terrific', 'JJ'), ('performance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('alcoholic', 'JJ'), ('director', 'NN')]),
#   Tree('NP', [('chris', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('georgetown', 'NN')]),
#   Tree('NP', [('kitty', 'JJ'), ('winn', 'NN')]),
#   Tree('NP', [('sharon', 'JJ'), ('spencer', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('secretary', 'NN')]),
#   Tree('NP', [('chris', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('line', 'NN')]),
#   Tree('NP', [('fire', 'NN')]),
#   Tree('NP', [('chris', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film.max', 'NN')]),
#   Tree('NP', [('von', 'NN')]),
#   Tree('NP', [('sydow', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('lancester', 'NN')]),
#   Tree('NP', [('merrin', 'NN')]),
#   Tree('NP', [('priest', 'NN')]),
#   Tree('NP', [('battle', 'NN')]),
#   Tree('NP', [('effect', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('scene', 'NN')]),
#   Tree('NP', [('sydow', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('battle', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('small', 'JJ'), ('complaint', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('character', 'NN')]),
#   Tree('NP', [('lt.', 'JJ'), ('kinderman', 'NN')]),
#   Tree('NP', [('lee', 'JJ'), ('j.', 'NN')]),
#   Tree('NP', [('cobb', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('character', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fault', 'NN')]),
#   Tree('NP', [('cobb', 'NN')]),
#   Tree('NP', [('usual', 'JJ'), ('stalwart', 'NN')]),
#   Tree('NP', [('self', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('role', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('whole', 'JJ'), ('character', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('few', 'JJ'), ('brief', 'NN')]),
#   Tree('NP', [('way', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('chris', 'NN')]),
#   Tree('NP', [('kinderman', 'NN')]),
#   Tree('NP', [('investigation', 'NN')]),
#   Tree('NP', [('columbo', 'NN')]),
#   Tree('NP', [('peter', 'NN')]),
#   Tree('NP', [('falk', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('kinderman', 'NN')]),
#   Tree('NP', [('memory', 'NN')]),
#   Tree('NP', [('one.as', 'NN')]),
#   Tree('NP', [('director', 'NN')]),
#   Tree('NP', [('william', 'NN')]),
#   Tree('NP', [('friedken', 'NN')]),
#   Tree('NP', [('director', 'NN')]),
#   Tree('NP', [('award', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('french', 'JJ'), ('connection', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('defining', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('final', 'JJ'), ('half', 'NN')]),
#   Tree('NP', [('hour', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('dynamic', 'JJ'), ('today', 'NN')]),
#   Tree('NP', [('french', 'JJ'), ('connection', 'NN')]),
#   Tree('NP', [('car', 'NN')]),
#   Tree('NP', [('chase', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('today', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('joke', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('linda', 'NN')]),
#   Tree('NP', [('blair', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('serious', 'JJ'), ('vein', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('creature', 'NN')]),
#   Tree('NP', [('feature', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('little', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('pea', 'NN')]),
#   Tree('NP', [('soup', 'NN')]),
#   Tree('NP', [('head', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('ultimate', 'JJ'), ('battle', 'NN')]),
#   Tree('NP', [('hell', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('total', 'JJ'), ('degradation', 'NN')]),
#   Tree('NP', [('innocence', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('study', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('faith', 'NN')]),
#   Tree('NP', [('belief', 'NN')]),
#   Tree('NP', [('god', 'NN')]),
#   Tree('NP', [('mankind', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('life', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('little', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('control.call', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('religious', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('sense', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('word', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('kind', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('choice', 'NN')]),
#   Tree('NP', [('grade', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('exorcist', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('real', 'JJ'), ('life', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('only', 'JJ'), ('thing', 'NN')]),
#   Tree('NP', [('good', 'JJ'), ('drama', 'NN')]),
#   Tree('NP', [('ellen', 'NN')]),
#   Tree('NP', [('burstyn', 'NN')]),
#   Tree('NP', [('place', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('mother', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('clue', 'NN')]),
#   Tree('NP', [('daughter', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('patronizing', 'NN')]),
#   Tree('NP', [('useless', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('parallel', 'JJ'), ('drama', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('crisis', 'NN')]),
#   Tree('NP', [('faith', 'NN')]),
#   Tree('NP', [('conscience', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('death', 'NN')]),
#   Tree('NP', [('mother', 'NN')]),
#   Tree('NP', [('part', 'NN')]),
#   Tree('NP', [('cast', 'NN')]),
#   Tree('NP', [('old', 'JJ'), ('veteran', 'NN')]),
#   Tree('NP', [('lee', 'NN')]),
#   Tree('NP', [('j.', 'NN')]),
#   Tree('NP', [('cobb', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cop', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('plot', 'NN')]),
#   Tree('NP', [('i', 'JJ'), ('mean', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('girl', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('window', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('noir', 'JJ'), ('character', 'NN')]),
#   Tree('NP', [('search', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('villain', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('connection', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('girl', 'NN')]),
#   Tree('NP', [('georgetown', 'NN')]),
#   Tree('NP', [('washington', 'NN')]),
#   Tree('NP', [('d.c.', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('artifact', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('foreign', 'JJ'), ('land', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('connection', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('window', 'NN')]),
#   Tree('NP', [('night', 'NN')]),
#   Tree('NP', [('washington', 'NN')]),
#   Tree('NP', [('d.c', 'NN')]),
#   Tree('NP', [('somebody', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('demon', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('window', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('big', 'JJ'), ('city', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('production', 'NN')]),
#   Tree('NP', [('linda', 'NN')]),
#   Tree('NP', [('blair', 'NN')]),
#   Tree('NP', [('fact', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('radiology', 'NN')]),
#   Tree('NP', [('technician', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('hospital', 'NN')]),
#   Tree('NP', [('scene', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('legitimate', 'JJ'), ('active', 'JJ'), ('serial', 'JJ'), ('killer', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('filming', 'NN')]),
#   Tree('NP', [('max', 'NN')]),
#   Tree('NP', [('von', 'NN')]),
#   Tree('NP', [('sydow', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('old', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('spider', 'NN')]),
#   Tree('NP', [('walk', 'NN')]),
#   Tree('NP', [('scene', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('idea', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('original', 'JJ'), ('release', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('sledgehammer', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('face', 'NN')]),
#   Tree('NP', [('second', 'JJ'), ('thought', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('reason', 'NN')])],
#  [Tree('NP', [('none', 'NN')]),
#   Tree('NP', [('power', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('head', 'NN')]),
#   Tree('NP', [('round', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('vomit', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('crucifix', 'NN')]),
#   Tree('NP', [('masturbation', 'NN')]),
#   Tree('NP', [('scene.that', 'NN')]),
#   Tree('NP', [('you.it', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('material', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('language', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('edge', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('variation', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('c-word', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('other', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('direction', 'NN')]),
#   Tree('NP', [('surprise', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('state', 'NN')]),
#   Tree('NP', [('security', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('bad', 'JJ'), ('dream', 'NN')]),
#   Tree('NP', [('from.it', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('screenplay', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('unspeakable', 'JJ'), ('trauma', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('edge', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('disbelief.the', 'NN')]),
#   Tree('NP', [('exorcist', 'NN')]),
#   Tree('NP', [('magic', 'NN')])],
#  [Tree('NP', [('a', 'DT'), ('lot', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('particular', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('gothic', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('example', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('conjuring', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('way', 'NN')]),
#   Tree('NP', [('none', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('mysterious', 'JJ'), ('introduction', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('old', 'JJ'), ('priest', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('prominent', 'JJ'), ('role', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('character', 'NN')]),
#   Tree('NP', [('young', 'JJ'), ('priest', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('set', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('important', 'JJ'), ('aspect', 'NN')]),
#   Tree('NP', [('horror', 'NN')]),
#   Tree('NP', [('today', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('dread', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('opening', 'NN')]),
#   Tree('NP', [('terrifying', 'JJ'), ('vibe', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('tension', 'NN')]),
#   Tree('NP', [('holy', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('true', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('technology', 'NN')]),
#   Tree('NP', [('cgi', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('entire', 'JJ'), ('bed', 'NN')]),
#   Tree('NP', [('shake', 'NN')]),
#   Tree('NP', [('degree', 'NN')]),
#   Tree('NP', [('turn', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('awesome', 'JJ'), ('effect', 'NN')]),
#   Tree('NP', [('way', 'NN')]),
#   Tree('NP', [('cgi', 'NN')]),
#   Tree('NP', [('ouija', 'JJ'), ('board', 'NN')]),
#   Tree('NP', [('exorcism', 'NN')]),
#   Tree('NP', [('clichés', 'NN')]),
#   Tree('NP', [('many', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('corny', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('gothic', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('masterpiece', 'NN')]),
#   Tree('NP', [('good', 'JJ'), ('god', 'NN')]),
#   Tree('NP', [('almighty', 'NN')]),
#   Tree('NP', [('those', 'DT'), ('stupid', 'JJ'), ('movies.conclusion', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('fan', 'NN')]),
#   Tree('NP', [('clichéd', 'NN')]),
#   Tree('NP', [('clichés', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('fresh', 'JJ'), ('mind', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('it.rating.score', 'NN')]),
#   Tree('NP', [('a+', 'NN')])]]
